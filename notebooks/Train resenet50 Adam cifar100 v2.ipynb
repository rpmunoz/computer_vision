# %% [markdown]
# # Initial Setup

# %%
import os
import numpy as np
import datetime
import time
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.python.util.tf_export import keras_export

print(tf.__version__)
# Out:
# 2.2.0

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Read dataset

# %%
dataDir = '/data/datasets/cifar100/raw'

configDir = 'config'
resultsDir = 'results'
modelsDir = 'models/cifar100_resnet50_adam_v2'
logsDir = 'logs/cifar100_resnet50_adam_v2'

# %%
BATCH_SIZE = 128
NUM_EPOCHS = 200
AUTOTUNE = tf.data.experimental.AUTOTUNE

NUM_CLASSES = 100
IMG_HEIGHT = 32
IMG_WIDTH = 32
NUM_CHANNELS = 3
IMG_SIZE = (IMG_HEIGHT, IMG_WIDTH)

# %%
if not os.path.exists(configDir):
  os.makedirs(configDir)

if not os.path.exists(resultsDir):
  os.makedirs(resultsDir)

if not os.path.exists(modelsDir):
  os.makedirs(modelsDir)
        
if not os.path.exists(logsDir):
  os.makedirs(logsDir)

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        cifar_dict = pickle.load(fo, encoding='bytes')
    return cifar_dict

# %%
def show_batch(image_batch, label_batch):
  plt.figure(figsize=(10,10))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(image_batch[n])
      plt.title(CLASS_NAMES[label_batch[n]==1][0].title())
      plt.axis('off')

# %%
meta = unpickle(os.path.join(dataDir, 'meta'))
train = unpickle(os.path.join(dataDir, 'train'))
test = unpickle(os.path.join(dataDir, 'test'))

# %%
classDF = pd.DataFrame(meta[b'fine_label_names'], columns = ['Classes'], dtype=str)
CLASS_NAMES = np.array(classDF['Classes'])

# %%
trainX = np.vstack(train[b"data"])
trainX = trainX.reshape(len(trainX), NUM_CHANNELS, IMG_HEIGHT, IMG_WIDTH).transpose(0,2,3,1).astype("float32")/255
trainY = np.array(train[b'fine_labels'])
trainY = tf.one_hot(trainY, NUM_CLASSES)

testX = np.vstack(test[b"data"])
testX = testX.reshape(len(testX), NUM_CHANNELS, IMG_HEIGHT, IMG_WIDTH).transpose(0,2,3,1).astype("float32")/255
testY = np.array(test[b'fine_labels'])#.reshape(-1,1)
testY = tf.one_hot(testY, NUM_CLASSES)

# %%
print(trainX.shape)
print(testX.shape)

print(trainY.shape)
print(testY.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000, 100)
# (10000, 100)

# %%
aug = keras.preprocessing.image.ImageDataGenerator(rotation_range=18, zoom_range=0.15,
                                                   width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
                                                   horizontal_flip=True, fill_mode="nearest")

# %% [markdown]
# ## Create model

# %%
modelDiagramFile = os.path.join(resultsDir, 'model_resnet50_cifar100.png')

resnet50 = tf.keras.applications.ResNet50(weights=None, include_top=False)
model = tf.keras.Sequential([resnet50, layers.GlobalAveragePooling2D(), layers.Dense(NUM_CLASSES, activation='softmax')])

keras.utils.plot_model(model, to_file=modelDiagramFile, show_shapes=True)

# %% [markdown]
# ## Train model

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
        
    tf.summary.scalar('learning rate', data=lr, step=epoch)
    print('Learning rate: ', lr)
    return lr

# %%
logsCheckDir = os.path.join(logsDir, datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
file_writer = tf.summary.create_file_writer(logsCheckDir + "/metrics")
file_writer.set_as_default()

tb_callback = keras.callbacks.TensorBoard(log_dir=logsCheckDir, histogram_freq=1)
ck_callback = keras.callbacks.ModelCheckpoint(os.path.join(modelsDir, "model_checkpoint_{epoch}.h5"))
lr_callback = keras.callbacks.LearningRateScheduler(lr_schedule)

callbacks = [tb_callback, ck_callback, lr_callback]

optimizer = tf.optimizers.Adam(learning_rate=lr_schedule(0))

model.compile(optimizer=optimizer,
              loss="categorical_crossentropy",
              metrics=["accuracy"])
# Out:
# Learning rate:  0.001

# %%
startTime = time.time()

model.fit(x=aug.flow(trainX, trainY, batch_size=BATCH_SIZE),
          validation_data=(testX, testY),
          epochs=NUM_EPOCHS,
          callbacks=callbacks,
          validation_freq=1)

endTime = time.time()

elapsedTime = (endTime - startTime)/60.
print("\nTotal time for model training: {} minutes".format(elapsedTime))
# Out:
# Learning rate:  0.001
# Epoch 1/200
# 391/391 [==============================] - 36s 92ms/step - loss: 4.8137 - accuracy: 0.0568 - val_loss: 245.5001 - val_accuracy: 0.0447 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/200
# 391/391 [==============================] - 35s 88ms/step - loss: 4.1991 - accuracy: 0.0997 - val_loss: 4.2028 - val_accuracy: 0.0686 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/200
# 391/391 [==============================] - 35s 89ms/step - loss: 3.9978 - accuracy: 0.1251 - val_loss: 89.0671 - val_accuracy: 0.0655 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/200
# 391/391 [==============================] - 35s 88ms/step - loss: 3.7598 - accuracy: 0.1532 - val_loss: 4.4900 - val_accuracy: 0.1405 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/200
# 391/391 [==============================] - 35s 89ms/step - loss: 4.1152 - accuracy: 0.1205 - val_loss: 84.1667 - val_accuracy: 0.1154 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/200
# 391/391 [==============================] - 34s 87ms/step - loss: 3.8307 - accuracy: 0.1568 - val_loss: 5.1285 - val_accuracy: 0.0438 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/200
# 391/391 [==============================] - 34s 87ms/step - loss: 3.9223 - accuracy: 0.1363 - val_loss: 17.6448 - val_accuracy: 0.1480 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/200
# 391/391 [==============================] - 35s 89ms/step - loss: 3.5778 - accuracy: 0.1667 - val_loss: 3.6644 - val_accuracy: 0.1933 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/200
# 391/391 [==============================] - 35s 88ms/step - loss: 3.5287 - accuracy: 0.1831 - val_loss: 3.1744 - val_accuracy: 0.2249 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/200
# 391/391 [==============================] - 34s 86ms/step - loss: 3.3349 - accuracy: 0.2062 - val_loss: 4.0881 - val_accuracy: 0.2260 - lr: 0.0010
# Learning rate:  0.001
# Epoch 11/200
# 391/391 [==============================] - 34s 88ms/step - loss: 3.2702 - accuracy: 0.2180 - val_loss: 3.6333 - val_accuracy: 0.2324 - lr: 0.0010
# Learning rate:  0.001
# Epoch 12/200
# 391/391 [==============================] - 34s 88ms/step - loss: 3.1699 - accuracy: 0.2357 - val_loss: 3.8921 - val_accuracy: 0.2687 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/200
# 391/391 [==============================] - 34s 88ms/step - loss: 3.1571 - accuracy: 0.2463 - val_loss: 4.7877 - val_accuracy: 0.2773 - lr: 0.0010
# Learning rate:  0.001
# Epoch 14/200
# 391/391 [==============================] - 34s 88ms/step - loss: 3.1602 - accuracy: 0.2406 - val_loss: 5.1481 - val_accuracy: 0.2636 - lr: 0.0010
# Learning rate:  0.001
# Epoch 15/200
# 391/391 [==============================] - 34s 88ms/step - loss: 3.0199 - accuracy: 0.2622 - val_loss: 28.7669 - val_accuracy: 0.1697 - lr: 0.0010
# Learning rate:  0.001
# Epoch 16/200
# 391/391 [==============================] - 34s 88ms/step - loss: 2.9841 - accuracy: 0.2702 - val_loss: 3.2966 - val_accuracy: 0.2848 - lr: 0.0010
# Learning rate:  0.001
# Epoch 17/200
# 391/391 [==============================] - 34s 87ms/step - loss: 2.8738 - accuracy: 0.2882 - val_loss: 3.8279 - val_accuracy: 0.2923 - lr: 0.0010
# Learning rate:  0.001
# Learning rate:  0.001
# Epoch 78/200
# 391/391 [==============================] - 31s 80ms/step - loss: 0.6238 - accuracy: 0.8098 - val_loss: 10.7531 - val_accuracy: 0.3097 - lr: 0.0010
# Learning rate:  0.001
# Epoch 79/200
# 391/391 [==============================] - 31s 80ms/step - loss: 0.6728 - accuracy: 0.7973 - val_loss: 3.9960 - val_accuracy: 0.3697 - lr: 0.0010
# Learning rate:  0.001
# Epoch 80/200
# 391/391 [==============================] - 31s 81ms/step - loss: 0.5042 - accuracy: 0.8452 - val_loss: 3.9431 - val_accuracy: 0.3750 - lr: 0.0010
# Learning rate:  0.001
# Epoch 81/200
# 391/391 [==============================] - 32s 81ms/step - loss: 0.4985 - accuracy: 0.8460 - val_loss: 4.1299 - val_accuracy: 0.3898 - lr: 0.0010
# Learning rate:  0.0001
# Epoch 82/200
# 391/391 [==============================] - 32s 81ms/step - loss: 0.3495 - accuracy: 0.8941 - val_loss: 4.0015 - val_accuracy: 0.3980 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 83/200
# 391/391 [==============================] - 32s 81ms/step - loss: 0.2969 - accuracy: 0.9106 - val_loss: 3.9986 - val_accuracy: 0.3991 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 84/200
# 391/391 [==============================] - 32s 81ms/step - loss: 0.2640 - accuracy: 0.9197 - val_loss: 4.0912 - val_accuracy: 0.4015 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 85/200
# 391/391 [==============================] - 32s 81ms/step - loss: 0.2570 - accuracy: 0.9222 - val_loss: 4.1055 - val_accuracy: 0.4018 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 86/200
# 391/391 [==============================] - 31s 80ms/step - loss: 0.2404 - accuracy: 0.9292 - val_loss: 4.3441 - val_accuracy: 0.3953 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 87/200
# 391/391 [==============================] - 31s 80ms/step - loss: 0.2266 - accuracy: 0.9328 - val_loss: 4.3997 - val_accuracy: 0.3990 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 88/200
# 391/391 [==============================] - 32s 81ms/step - loss: 0.2175 - accuracy: 0.9357 - val_loss: 4.3283 - val_accuracy: 0.3989 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 89/200
# 391/391 [==============================] - 32s 81ms/step - loss: 0.2123 - accuracy: 0.9378 - val_loss: 4.4820 - val_accuracy: 0.4010 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 90/200
# 391/391 [==============================] - 32s 83ms/step - loss: 0.2096 - accuracy: 0.9395 - val_loss: 4.3661 - val_accuracy: 0.4003 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 91/200
# 391/391 [==============================] - 31s 80ms/step - loss: 0.2269 - accuracy: 0.9313 - val_loss: 5.9856 - val_accuracy: 0.3954 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 92/200
# 103/391 [======>.......................] - ETA: 18s - loss: 0.2115 - accuracy: 0.9374
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-c53f72080ab9> in <module>
#       5           epochs=NUM_EPOCHS,
#       6           callbacks=callbacks,
# ----> 7           validation_freq=1)
#       8
#       9 endTime = time.time()
#
# /data/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /data/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     853                 context.async_wait()
#     854               logs = tmp_logs  # No error, now safe to assign to logs.
# --> 855               callbacks.on_train_batch_end(step, logs)
#     856         epoch_logs = copy.copy(logs)
#     857
#
# /data/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     387     """
#     388     if self._should_call_train_batch_hooks:
# --> 389       logs = self._process_logs(logs)
#     390       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     391
#
# /data/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in _process_logs(self, logs)
#     263     """Turns tensors into numpy arrays or Python scalars."""
#     264     if logs:
# --> 265       return tf_utils.to_numpy_or_python_type(logs)
#     266     return {}
#     267
#
# /data/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     521     return t  # Don't turn ragged or sparse tensors to NumPy.
#     522
# --> 523   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     524
#
# /data/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     615
#     616   return pack_sequence_as(
# --> 617       structure[0], [func(*x) for x in entries],
#     618       expand_composites=expand_composites)
#     619
#
# /data/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     615
#     616   return pack_sequence_as(
# --> 617       structure[0], [func(*x) for x in entries],
#     618       expand_composites=expand_composites)
#     619
#
# /data/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     517   def _to_single_numpy_or_python_type(t):
#     518     if isinstance(t, ops.Tensor):
# --> 519       x = t.numpy()
#     520       return x.item() if np.ndim(x) == 0 else x
#     521     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /data/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#     959     """
#     960     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 961     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     962     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     963
#
# /data/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#     925     # pylint: disable=protected-access
#     926     try:
# --> 927       return self._numpy_internal()
#     928     except core._NotOkStatusException as e:
#     929       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:
